# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Approach_1 = [270,3.3]
Approach_2 = [2.2,0.03]
phase = ["Training", "Testing"]
ind = np.arange(2)
width = 0.2

# %%
plt.figure()
plt.bar(ind,Approach_1, 0.2, label="Approach 1")
plt.bar(ind+width,Approach_2,0.2, label="Approach 2")
plt.legend()
